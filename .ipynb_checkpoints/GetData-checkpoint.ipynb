# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
import numpy as np
import pandas as pd
import requests
import time
from us import states
import json
from config import gkey

# %%
wine_df = pd.read_csv("winemag-data-130k-v2.csv", encoding='ISO-8859-1')
wine_df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                       Vulkíæ Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN     Kerin Oäó»Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                 Nicosia 2013 Vulkíæ Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2          @paulgwineæ      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4          @paulgwineæ  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
wine_df = wine_df[['country','description','designation','points','price','province','region_1','region_2', 'taster_name', 'title', 'variety','winery']]
wine_df = wine_df.dropna(subset=['province', 'points','price'])
wine_provinces = wine_df.groupby(['province'], as_index=False).mean()
wine_provinces.head()
# Out:
#            province     points      price
# 0            Achaia  85.800000  23.000000
# 1   Aconcagua Costa  87.629630  23.074074
# 2  Aconcagua Valley  88.192982  40.298246
# 3            Aegean  88.954545  33.409091
# 4       Agioritikos  86.333333  24.000000

# %%
lat = []
lon = []
provinces = []

for province in wine_provinces['province']:
    target_url = ('https://maps.googleapis.com/maps/api/geocode/json?' 
    'address={0}&key={1}').format(province, gkey)
    response = requests.get(target_url)
    if response.ok:
        print(f'processing {province}')
        geo_data = response.json()
        if geo_data['results']:
            lat.append(geo_data["results"][0]["geometry"]["location"]["lat"])
            lon.append(geo_data["results"][0]["geometry"]["location"]["lng"])
            provinces.append(province)
        else:
            print('Skipping %s because no data'%province)
    else:
        print('Got error on %s'%target_url)
        print(response)
# Out:
# processing Achaia
# processing Aconcagua Costa
# processing Aconcagua Valley
# processing Aegean
# processing Agioritikos
# Skipping Agioritikos because no data
# processing Ahr
# processing Alenquer
# processing Alentejano
# processing Alentejo
# processing Alenteo
# processing Algarve
# processing Alsace
# processing America
# processing Amindeo
# processing Amyndeon
# processing Andalucia
# processing Ankara
# processing Apalta
# processing Arcadia
# processing Arizona
# processing Armenia
# processing Atalanti Valley
# processing Atlantida
# Skipping Atlantida because no data
# processing Attica
# processing Australia Other
# processing Austria
# processing Awatere Valley
# processing Baden
# processing Bairrada
# processing Beaujolais
# processing Beira Atlantico
# processing Beira Interior
# processing Beiras
# processing Bekaa Valley
# processing Beotia
# processing Black Sea Coastal
# processing Bordeaux
# processing Bot River
# processing Brazil
# processing Brda
# processing Breede River Valley
# processing Breedekloof
# processing British Columbia
# processing Bucelas
# processing Buin
# processing Bulgaria
# processing Burgenland
# processing Burgundy
# processing Bí_o Bí_o Valley
# processing Cachapoal Valley
# processing Cahul
# processing California
# processing Campanha
# processing Canada Other
# Skipping Canada Other because no data
# processing Canelones
# processing Canterbury
# processing Cape Agulhas
# processing Cape Peninsula
# processing Cape South Coast
# processing Cappadocia
# processing Carnuntum
# processing Casablanca & Leyda Valleys
# processing Casablanca Valley
# processing Casablanca-Curicí_ Valley
# Skipping Casablanca-Curicí_ Valley because no data
# processing Catalonia
# processing Cauquenes Valley
# processing Cederberg
# processing Central Greece
# processing Central Italy
# processing Central Otago
# processing Central Spain
# processing Central Valley
# processing Cephalonia
# processing Chalkidiki
# processing Champagne
# processing Chile
# processing China
# processing Choapa Valley
# processing Coastal Region
# processing Codru Region
# processing Coelemu
# processing Colares
# processing Colchagua Costa
# processing Colchagua Valley
# processing Colorado
# processing Commandaria
# Skipping Commandaria because no data
# processing Connecticut
# processing Constantia
# processing Corinth
# processing Corinthia
# Skipping Corinthia because no data
# processing Crete
# processing Croatia
# processing Curicí_ Valley
# Skipping Curicí_ Valley because no data
# processing Curicí_ and Leyda Valleys
# processing Curicí_ and Maipo Valleys
# processing Cyclades
# processing Cyprus
# processing Dalmatian Coast
# Skipping Dalmatian Coast because no data
# processing Dan
# processing Danube River Plains
# processing Darling
# processing Dealu Mare
# Got error on https://maps.googleapis.com/maps/api/geocode/json?address=Dealurile Hu»ilor&key=AIzaSyDY10nrK-9h440w_wX0KkaiAGU3ZBCo5o0
# <Response [400]>
# processing Dealurile Munteniei
# Skipping Dealurile Munteniei because no data
# processing Devon Valley
# Got error on https://maps.googleapis.com/maps/api/geocode/json?address=DingaÛ&key=AIzaSyDY10nrK-9h440w_wX0KkaiAGU3ZBCo5o0
# <Response [400]>
# processing Dolenjska
# processing Douro
# processing Drama
# processing Durbanville
# processing Duriense
# Skipping Duriense because no data
# processing Dí£o
# Skipping Dí£o because no data
# processing East Coast
# processing Eger
# processing Eilandia
# processing Eisenberg
# processing ElazÛ±Ûô
# Skipping ElazÛ±Ûô because no data
# processing ElazÛ±Ûô-Diyarbakir
# processing Elgin
# processing Elim
# processing Ella Valley
# processing Elqui Valley
# processing England
# processing Epanomi
# processing Estremadura
# processing Florina
# processing France Other
# Skipping France Other because no data
# processing Franken
# Skipping Franken because no data
# processing Franschhoek
# Got error on https://maps.googleapis.com/maps/api/geocode/json?address=Fruçka Gora&key=AIzaSyDY10nrK-9h440w_wX0KkaiAGU3ZBCo5o0
# <Response [400]>
# processing Galicia
# processing Galil
# processing Galilee
# Skipping Galilee because no data
# processing Georgia
# processing Germany
# processing Gisborne
# processing Gladstone
# processing Golan Heights
# processing Goriska Brda
# processing Goumenissa
# processing Greece
# processing Groenekloof
# Skipping Groenekloof because no data
# processing Guerrouane
# Skipping Guerrouane because no data
# processing Halkidiki
# processing Haut-Judeí©
# Skipping Haut-Judeí© because no data
# processing Hawaii
# processing Hawke's Bay
# processing Helderberg
# processing Hemel en Aarde
# processing Hrvatsko Primorje
# processing Hungary
# processing Hvar
# processing Ica
# processing Idaho
# processing Illinois
# processing Imathia
# processing Iowa
# processing Ismarikos
# Skipping Ismarikos because no data
# processing Israel
# processing Istria
# processing Italy Other
# Skipping Italy Other because no data
# processing Itata Valley
# processing Jerusalem Hills
# processing Jidvei
# processing Jonkershoek Valley
# processing Juanico
# processing Judean Hills
# processing Kakheti
# processing Kamptal
# processing Kathikas
# processing Kentucky
# processing Korinthia
# Got error on https://maps.googleapis.com/maps/api/geocode/json?address=KorÛula&key=AIzaSyDY10nrK-9h440w_wX0KkaiAGU3ZBCo5o0
# <Response [400]>
# processing Krania Olympus
# Skipping Krania Olympus because no data
# processing Kras
# Skipping Kras because no data
# processing Kremstal
# processing Krk
# processing Kumeu
# processing Kutjevo
# processing Lakonia
# processing Landwein Rhein
# processing Languedoc-Roussillon
# processing Lebanon
# processing Leithaberg
# processing Lemesos
# processing Lesbos
# processing Letrinon
# processing Levante
# processing Leyda Valley
# processing Leyda Valley-Maipo Valley
# processing Limarí_ Valley
# processing Limnos
# processing Lisboa
# processing Loire Valley
# processing Lolol Valley
# processing Lombardy
# processing Loncomilla Valley
# Skipping Loncomilla Valley because no data
# processing Lontuí© Valley
# Skipping Lontuí© Valley because no data
# processing Lutzville Valley
# processing Macedonia
# processing Madeira
# processing Maipo Valley
# processing Maipo Valley-Colchagua Valley
# processing Malgas
# processing Malleco
# processing Mantinia
# processing Marchigue
# processing Markopoulo
# processing Marlborough
# processing Martinborough
# processing Massachusetts
# processing Maule Valley
# processing Mavrodaphne de Cephalonie
# processing Mavrodaphne of Patras
# processing Mendoza Province
# processing Messinia
# processing Michigan
# processing Middle and South Dalmatia
# Skipping Middle and South Dalmatia because no data
# processing Minho
# processing Missouri
# processing Mittelburgenland
# processing Mittelrhein
# processing Moldova
# processing Molina
# processing Monemvasia
# processing Montevideo
# processing Moravia
# processing Morocco
# processing Moscatel de Setí_bal
# processing Moscatel do Douro
# Skipping Moscatel do Douro because no data
# processing Mosel
# processing Mosel-Saar-Ruwer
# processing Moselle Luxembourgeoise
# processing Mostar
# processing Mount Athos
# processing Murfatlar
# processing Muscat of Kefallonian
# processing Muscat of Patras
# processing Muzla
# processing Míçtra
# Skipping Míçtra because no data
# processing Nahe
# processing Naoussa
# processing Nashik
# processing Negev
# processing Negev Hills
# processing Nelson
# processing Nemea
# processing Neuchí¢tel
# Skipping Neuchí¢tel because no data
# processing Neusiedlersee
# processing Nevada
# processing New Jersey
# processing New Mexico
# processing New South Wales
# processing New York
# processing New Zealand
# processing Niederí_sterreich
# Skipping Niederí_sterreich because no data
# processing North Carolina
# processing North Dalmatia
# Skipping North Dalmatia because no data
# processing Northeastern Italy
# processing Northern Cape
# processing Northern Spain
# processing Northwestern Italy
# processing Obidos
# processing Ohio
# processing Olifants River
# processing Ontario
# processing Oregon
# processing Other
# processing Overberg
# processing Paardeberg
# Skipping Paardeberg because no data
# processing Paarl
# processing Pafos
# processing Pageon
# Skipping Pageon because no data
# processing Palmela
# processing Panciu
# processing Pangeon
# processing Patras
# processing Peljesac
# processing Peloponnese
# processing Pennsylvania
# processing Pení_nsula de Setí_bal
# processing Peumo
# processing Pfalz
# processing Philadelphia
# processing Piedmont
# processing Pinto Bandeira
# processing Pirque
# processing Pitsilia Mountains
# Skipping Pitsilia Mountains because no data
# processing Pocerina
# Skipping Pocerina because no data
# processing Podunavlje
# Skipping Podunavlje because no data
# processing Polkadraai Hills
# processing Port
# processing Portugal
# processing Portuguese Table Wine
# processing Primorska
# processing Progreso
# processing Provence
# processing Puente Alto
# processing Rapel Valley
# processing Rapsani
# processing Recas
# processing Requinoa
# processing Retsina
# processing Rheingau
# processing Rheinhessen
# Skipping Rheinhessen because no data
# processing Rhode Island
# processing RhíÇne Valley
# Skipping RhíÇne Valley because no data
# processing Ribatejano
# Skipping Ribatejano because no data
# processing Ribatejo
# processing Rio Claro
# processing Robertson
# processing Romania
# processing Sagrada Familia
# processing Samos
# processing Samson
# processing San Antonio
# processing San Antonio de las Minas Valley
# processing San Clemente
# processing San Jose
# processing San Vicente
# processing Santa Catarina
# processing Santa Cruz
# processing Santorini
# processing Sebes
# processing Serra Gaí_cha
# Skipping Serra Gaí_cha because no data
# processing Serra do Sudeste
# processing Setubal
# processing Shomron
# processing Sicily & Sardinia
# processing Simonsberg-Paarl
# processing Simonsberg-Stellenbosch
# processing Sithonia
# processing Slovenia
# processing Slovenska Istra
# processing Sopron
# processing South Africa
# processing South Australia
# processing South Island
# processing Southern Italy
# processing Southwest France
# processing Spain Other
# processing Spanish Islands
# Skipping Spanish Islands because no data
# processing Steiermark
# processing Stellenbosch
# processing Sterea Ellada
# processing Swartland
# processing Switzerland
# processing Szekszíçrd
# Skipping Szekszíçrd because no data
# processing Sí_dburgenland
# Skipping Sí_dburgenland because no data
# processing Sí_doststeiermark
# Skipping Sí_doststeiermark because no data
# processing Sí_dsteiermark
# Skipping Sí_dsteiermark because no data
# processing Table wine
# processing Tarnave
# processing Tasmania
# processing Tejo
# processing Terras do Dí£o
# Skipping Terras do Dí£o because no data
# processing Terras do Sado
# Skipping Terras do Sado because no data
# processing Texas
# processing Thermenregion
# Skipping Thermenregion because no data
# processing Thessalikos
# Skipping Thessalikos because no data
# processing Thrace
# Skipping Thrace because no data
# processing Thracian Valley
# processing Thraki
# processing Ticino
# processing Tikves
# processing Tokaj
# processing Tokaji
# processing Traisental
# processing Tríçs-os-Montes
# Skipping Tríçs-os-Montes because no data
# processing Tulbagh
# processing Turkey
# processing Tuscany
# processing Tíçvora-Varosa
# Skipping Tíçvora-Varosa because no data
# processing Ukraine
# processing Upper Galilee
# processing Urla-Thrace
# Skipping Urla-Thrace because no data
# processing Uruguay
# processing Valais
# processing Vale Trentino
# processing Vale dos Vinhedos
# processing Valle de Guadalupe
# processing Veneto
# processing Vermont
# processing Victoria
# processing Vienna
# processing Viile Timis
# processing Viile Timisului
# processing Villíçny
# Skipping Villíçny because no data
# processing Vin de Pays de Velvendo
# Skipping Vin de Pays de Velvendo because no data
# processing Vinho Espumante
# Skipping Vinho Espumante because no data
# processing Vinho Espumante de Qualidade
# processing Vinho Licoroso
# Skipping Vinho Licoroso because no data
# processing Vinho Verde
# processing Vinho da Mesa
# Skipping Vinho da Mesa because no data
# processing Vipavska Dolina
# processing Virginia
# processing Vlootenburg
# processing Ví¢nju Mare
# Skipping Ví¢nju Mare because no data
# processing Wachau
# processing Wagram
# processing Wagram-Donauland
# processing Waiheke Island
# processing Waipara
# processing Waipara Valley
# processing Wairarapa
# processing Wairau Valley
# processing Waitaki Valley
# processing Walker Bay
# processing Washington
# processing Washington-Oregon
# processing Weinland í_sterreich
# Skipping Weinland í_sterreich because no data
# processing Weinviertel
# processing Wellington
# processing Western Australia
# processing Western Cape
# processing Wiener Gemischter Satz
# processing Wí_rttemberg
# Skipping Wí_rttemberg because no data
# processing Zenata
# Skipping Zenata because no data
# Got error on https://maps.googleapis.com/maps/api/geocode/json?address=_upa&key=AIzaSyDY10nrK-9h440w_wX0KkaiAGU3ZBCo5o0
# <Response [400]>
# Got error on https://maps.googleapis.com/maps/api/geocode/json?address=ætajerska&key=AIzaSyDY10nrK-9h440w_wX0KkaiAGU3ZBCo5o0
# <Response [400]>
# processing í_sterreichischer Perlwein
# Skipping í_sterreichischer Perlwein because no data
# processing í_sterreichischer Sekt
# Skipping í_sterreichischer Sekt because no data

# %%
geo_dict = {
   "province": provinces,
    "lat": lat,
    "lon": lon,
}
geo_df = pd.DataFrame(geo_dict)
full_set = wine_df.merge(geo_df, how="left", on = 'province')
full_set = full_set.dropna(subset=['lat'])
full_set.head()
#add these to the dataframe
# Out:
#     country                                        description  \
# 0  Portugal  This is ripe and fruity, a wine that is smooth...
# 1        US  Tart and snappy, the flavors of lime flesh and...
# 2        US  Pineapple rind, lemon pith and orange blossom ...
# 3        US  Much like the regular bottling from 2012, this...
# 4     Spain  Blackberry and raspberry aromas show a typical...
#
#                           designation  points  price        province  \
# 0                            Avidagos      87   15.0           Douro
# 1                                 NaN      87   14.0          Oregon
# 2                Reserve Late Harvest      87   13.0        Michigan
# 3  Vintner's Reserve Wild Child Block      87   65.0          Oregon
# 4                        Ars In Vitro      87   15.0  Northern Spain
#
#               region_1           region_2         taster_name  \
# 0                  NaN                NaN          Roger Voss
# 1    Willamette Valley  Willamette Valley        Paul Gregutt
# 2  Lake Michigan Shore                NaN  Alexander Peartree
# 3    Willamette Valley  Willamette Valley        Paul Gregutt
# 4              Navarra                NaN   Michael Schachner
#
#                                                title             variety  \
# 0      Quinta dos Avidagos 2011 Avidagos Red (Douro)      Portuguese Red
# 1      Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 2  St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 3  Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 4  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
#
#                 winery        lat         lon
# 0  Quinta dos Avidagos  41.501277   -5.512293
# 1            Rainstorm  43.804133 -120.554201
# 2           St. Julian  44.314844  -85.602364
# 3         Sweet Cheeks  43.804133 -120.554201
# 4               Tandem  43.263588   -2.929068

# %%
gmaps.configure(api_key=gkey)
locations = full_set[["lat", "lon"]].astype(float)

ratings = full_set["points"].astype(float)

fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=ratings, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

# Adjust heat_layer setting to help with heatmap dissipating on zoom
heat_layer.dissipating = False
heat_layer.max_intensity = 100
heat_layer.point_radius = 1

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
